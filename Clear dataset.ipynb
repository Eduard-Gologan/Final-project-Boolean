# %% [markdown]
# In this notebook, we have to clear our dataset from the values which are null and nan. Then we have to order some datas and columns by ordering them in different ways.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
#We need to import our dataset which is in csv file format

Gdata=pd.read_csv(r'C:\Users\User\Dropbox\PC\Desktop\progetti data analyst\final project\guadagni per data.csv')
Bv=pd.read_csv(r'C:\Users\User\Dropbox\PC\Desktop\progetti data analyst\final project\Bilancio vendite.csv')
Cfedel=pd.read_csv(r'C:\Users\User\Dropbox\PC\Desktop\progetti data analyst\final project\città.csv')
Userfedel=pd.read_csv(r'C:\Users\User\Dropbox\PC\Desktop\progetti data analyst\final project\Utenti.csv')
TotOrdVend=pd.read_csv(r'C:\Users\User\Dropbox\PC\Desktop\progetti data analyst\final project\totale ordini venduti.csv')
Traffon=pd.read_csv(r'C:\Users\User\Dropbox\PC\Desktop\progetti data analyst\final project\Traffico online.csv')

# %%
#Now we have to clean the dataset from the null values, nan and duplicates.

Gdata=Gdata.dropna()
Gdata=Gdata.drop_duplicates()
Bv=Bv.dropna()
Bv=Bv.drop_duplicates()
Cfedel=Cfedel.dropna()
Cfedel=Cfedel.drop_duplicates()
Userfedel=Userfedel.dropna()
Userfedel=Userfedel.drop_duplicates()
TotOrdVend=TotOrdVend.dropna()
TotOrdVend=TotOrdVend.drop_duplicates()
Traffon=Traffon.dropna()
Traffon=Traffon.drop_duplicates()

#Now we have to order some variables by a determined value in desc order

Gdata=Gdata.sort_values(by="daily_sales",ascending=False)
Bv=Bv.sort_values(by="total_revenue",ascending = False)
Cfedel=Cfedel.sort_values(by="total_orders",ascending = False)
Userfedel=Userfedel.sort_values(by="user_count", ascending= False)
TotOrdVend=TotOrdVend.sort_values(by="total_units_sold", ascending= False)
Traffon=Traffon.sort_values(by ="visit_count", ascending= False)

# %%
#Now we print to see the dataset
#Gdata
#Bv
#Cfedel
#Userfedel
#TotOrdVend
#Traffon

# %%
#Now we have to import other csv files which come from the results of some queries in SQL

Cdistrb=pd.read_csv(r'C:\Users\User\Dropbox\PC\Desktop\progetti data analyst\final project\Analisi centri distribuzione.csv')
PerUt=pd.read_csv(r'C:\Users\User\Dropbox\PC\Desktop\progetti data analyst\final project\Analisi del percorso utente.csv')
Fedelcli=pd.read_csv(r'C:\Users\User\Dropbox\PC\Desktop\progetti data analyst\final project\Analisi fedeltà cliente.csv')
TraffSorg=pd.read_csv(r'C:\Users\User\Dropbox\PC\Desktop\progetti data analyst\final project\Analisi sorgenti di traffico.csv')
OrdStat=pd.read_csv(r'C:\Users\User\Dropbox\PC\Desktop\progetti data analyst\final project\Analisi stato ordini.csv')
Agegenddistr=pd.read_csv(r'C:\Users\User\Dropbox\PC\Desktop\progetti data analyst\final project\Distribuzione età e genere.csv')
GeoDistrib=pd.read_csv(r'C:\Users\User\Dropbox\PC\Desktop\progetti data analyst\final project\Distribuzione geografica.csv')
Prefgendage=pd.read_csv(r'C:\Users\User\Dropbox\PC\Desktop\progetti data analyst\final project\Preferenze per genere ed età.csv')
Inventpercateg=pd.read_csv(r'C:\Users\User\Dropbox\PC\Desktop\progetti data analyst\final project\Stato inventario per categorie.csv')
TopcategVend=pd.read_csv(r'C:\Users\User\Dropbox\PC\Desktop\progetti data analyst\final project\Top categorie per vendite.csv')
Trends=pd.read_csv(r'C:\Users\User\Dropbox\PC\Desktop\progetti data analyst\final project\Trend degli ordini nel tempo.csv')

# %%
#Now we have to clean the  new datasets from the null values, nan and duplicates.

Cdistrb=Cdistrb.dropna()
Cdistrb=Cdistrb.drop_duplicates()
PerUt=PerUt.dropna()
PerUt=PerUt.drop_duplicates()
Fedelcli=Fedelcli.dropna()
Fedelcli=Fedelcli.drop_duplicates()
TraffSorg=TraffSorg.dropna()
TraffSorg=TraffSorg.drop_duplicates()
OrdStat=OrdStat.dropna()
OrdStat=OrdStat.drop_duplicates()
Agegenddistr=Agegenddistr.dropna()
Agegenddistr=Agegenddistr.drop_duplicates()
GeoDistrib=GeoDistrib.dropna()
GeoDistrib=GeoDistrib.drop_duplicates()
Prefgendage=Prefgendage.dropna()
Prefgnedage=Prefgendage.drop_duplicates()
GeoDistrib=GeoDistrib.dropna()
GeoDistrib=GeoDistrib.drop_duplicates()
Prefgendage=Prefgendage.dropna()
Prefgendage=Prefgendage.drop_duplicates()
Inventpercateg=Inventpercateg.dropna()
Inventpercateg=Inventpercateg.drop_duplicates()
TopcategVend=TopcategVend.dropna()
TopcategVend=TopcategVend.drop_duplicates()
Trends=Trends.dropna()
Trends=Trends.drop_duplicates()

#Now we have to order some variables by a determined value in desc order

Cdistrb=Cdistrb.sort_values(by="total_inventory_items",ascending=False)
PerUt=PerUt.sort_values(by="event_count",ascending = False)
Fedelcli=Fedelcli.sort_values(by="customer_count",ascending = False)
TraffSorg=TraffSorg.sort_values(by="total_events", ascending= False)
OrdStat=OrdStat.sort_values(by="order_count", ascending= False)
Agegenddistr=Agegenddistr.sort_values(by ="user_count", ascending= False)
GeoDistrib=GeoDistrib.sort_values(by="user_count",ascending=False)
Prefgendage=Prefgendage.sort_values(by="purchases",ascending = False)
Inventpercateg=Inventpercateg.sort_values(by="total_inventory",ascending = False)
TopcategVend=TopcategVend.sort_values(by="units_sold", ascending= False)
Trends=Trends.sort_values(by="total_orders", ascending= False)

# %%
#Cdistrb
#PerUt
#Fedelcli
#TraffSorg
#OrdStat
#Agegenddistr
#GeoDistrib
#Prefgendage
#Inventpercateg
#TopcategVend
Trends
# Out:
#                        order_month  total_orders  total_items  \
# 77  2025-06-01 00:00:00.000000 UTC          9691      14183.0
# 76  2025-05-01 00:00:00.000000 UTC          6526       9498.0
# 75  2025-04-01 00:00:00.000000 UTC          5550       8007.0
# 74  2025-03-01 00:00:00.000000 UTC          5060       7370.0
# 72  2025-01-01 00:00:00.000000 UTC          4391       6275.0
# ..                             ...           ...          ...
# 4   2019-05-01 00:00:00.000000 UTC            99        144.0
# 3   2019-04-01 00:00:00.000000 UTC            66         98.0
# 2   2019-03-01 00:00:00.000000 UTC            51         71.0
# 1   2019-02-01 00:00:00.000000 UTC            24         41.0
# 0   2019-01-01 00:00:00.000000 UTC             6         10.0
#
#     unique_customers  avg_items_per_order
# 77              7661                 1.46
# 76              6026                 1.46
# 75              5222                 1.44
# 74              4801                 1.46
# ...
